# %%
import numpy as np
import pandas as pd
from plotnine import *
import random

# %%
data = []

i = 0
p = "tempdata/var/log/remote/wireless-encoded/wireless_10-04-2020.log"
#p = "tempdata/wireless_09-15-2020.log"
with open(p) as f:
    for line in f:
        l = f.readline()
        if l.find("Authentication Successful") > -1:
            data.append(l.split(" "))
#         data.append(l)
#         i += 1
#         if i > 10000:
#             break

# %%
df = pd.DataFrame(data)
#df = df15.copy()
# cols = [0,1,2,9,16]
# fdf = df.iloc[: , cols]
# renames = {key:val for val,key in zip(["month" , "day" , "time" , "ap" , "mac"],cols)}
# fdf = fdf.rename(renames, axis=1)
# fdf["ap"] = fdf["ap"].apply(lambda r : r.split("@")[0].lower())
# fdf["building"] = fdf["ap"].apply(lambda r : r[0:4].lower() if r.find("EXT") < 0 else  r[4:8].lower() )
# fdf['time'] = fdf["month"] + "-" + fdf["day"] + "-" +fdf["time"]
# fdf["time"] = pd.to_datetime(fdf["time"] , format="%b-%d-%H:%M:%S")
# fdf["time"] = fdf["time"].apply(lambda t : t.replace(year=2020))
# fdf["mac"] = fdf["mac"].apply(lambda r : r.strip(": "))
#fdf[fdf["user"] == "d0:d2:b0:92:df:70:"].groupby(pd.Grouper(key="time" , freq="15min")).size()

# %%
df.iloc[0,:]
# Out:
# 0                                                   Oct
# 1
# 2                                                     4
# 3                                              00:00:03
# 4                                            10.47.0.23
# 5                                        authmgr[1889]:
# 6                                              <522008>
# 7                                                <3736>
# 8                                                <NOTI>
# 9                                                     <
# 10                                          10.47.0.23>
# 11
# 12                                                 User
# 13                                       Authentication
# 14                                          Successful:
# 15    username=w4PDlcOGwpLCmFLCqMOpw6LDk8OWaMKUwpPDmMKD
# 16                                MAC=02:6e:30:36:34:de
# 17                                     IP=10.216.51.153
# 18                      role=ur_student_personal_device
# ...

# %%
df.iloc[:,18].unique()
# Out:
# array(['role=ur_student_personal_device', 'role=ur_facstaff_uncc_device',
#        'role=ur_facstaff_personal_device', 'role=ur_diningsvcs_device',
#        'role=ur_eduroam_guest', 'IP=fe80::4c9:d39:a636:4636',
#        'IP=10.216.43.28', 'role=ur_guest_personal_device',
#        'role=ur_student_uncc_device', 'role=ur_halton_media',
#        'IP=10.216.55.144', 'IP=fe80::7c6c:50ff:fec5:364d',
#        'IP=fe80::18e1:1b37:a686:566b', 'IP=10.22.64.56',
#        'IP=10.216.24.192', 'IP=fe80::465e:cdff:feb1:468c'], dtype=object)

# %%
df[df.iloc[:,18] == "role=ur_student_personal_device"].iloc[: , 16].unique()
# Out:
# array(['MAC=02:6e:30:36:34:de', 'MAC=42:17:ee:f0:6f:c1',
#        'MAC=e6:ef:3c:77:ce:c7', 'MAC=88:19:08:40:88:c3',
#        'MAC=d4:a3:3d:22:4f:98', 'MAC=c4:98:80:f2:ee:15',
#        'MAC=3a:b6:8a:03:f0:3f', 'MAC=82:7d:58:f0:f9:8e',
#        'MAC=dc:a9:04:d2:6c:18', 'MAC=6a:24:ac:65:3e:a6',
#        'MAC=66:51:52:96:df:fe', 'MAC=8e:66:df:ee:d2:49',
#        'MAC=4e:d3:50:5e:17:5e', 'MAC=f0:18:98:16:f9:51',
#        'MAC=a0:c9:a0:7e:3a:ce', 'MAC=92:e5:98:36:b6:ec',
#        'MAC=56:18:74:07:08:83', 'MAC=12:11:35:33:79:43',
#        'MAC=ae:74:58:0d:18:06', 'MAC=3e:ec:1c:e4:2f:d3',
#        'MAC=ac:bc:32:7c:91:67', 'MAC=50:82:d5:83:c1:7e',
#        'MAC=80:e6:50:14:2c:66', 'MAC=9c:e3:3f:a5:c4:6d',
#        'MAC=a2:2f:15:9a:05:9c', 'MAC=0e:c3:50:5f:ae:27',
#        'MAC=3c:22:fb:c4:70:02', 'MAC=2a:8e:85:d5:bc:1c',
#        'MAC=e8:fb:e9:38:c4:89', 'MAC=d4:61:da:14:a4:78',
#        'MAC=0a:c1:7e:a7:13:95', 'MAC=b2:55:e5:0c:de:1e',
# ...

# %%
df[df.iloc[:,18] == "role=ur_facstaff_personal_device"].iloc[: , 16].str.slice(4 ,).unique()
# Out:
# array(['c0:33:5e:0d:da:8f', '04:e5:36:1a:ae:21', 'd8:c4:97:fe:2f:79',
#        '64:5d:86:96:d4:26', 'd8:c4:97:fe:2d:e5', 'a4:e9:75:55:7c:61',
#        '40:83:de:f6:d9:2b', '40:d3:ae:e7:84:8c', '00:5b:94:1a:58:5c',
#        'a4:08:ea:25:86:07', '3c:cd:36:18:a6:85', 'd0:7f:a0:05:2d:fb',
#        '90:b6:86:b6:a4:72', 'c0:d3:c0:61:59:8f', 'ce:6c:44:15:f1:04',
#        'd8:c4:97:fd:73:d3', 'a4:08:ea:27:e6:13', 'c0:bd:c8:fc:36:ed',
#        'c0:d3:c0:75:46:cd', 'd8:c4:97:fe:35:4f', '00:12:cc:00:24:49',
#        'c0:d3:c0:61:59:d3', '00:12:cc:00:3c:3f', 'dc:f7:56:15:51:4e',
#        'a4:6c:f1:e7:fa:75', 'b4:ae:2b:e5:06:06', '00:12:cc:00:43:db',
#        '00:12:cc:00:26:71', 'd0:7f:a0:87:a8:73', '8c:c6:81:a5:f4:ec',
#        '3a:cd:90:41:0b:b5', 'd8:c4:97:fe:37:d7', 'd8:c4:97:fd:78:e5',
#        '0e:75:63:b2:0b:55', 'a4:08:ea:ab:a7:59', '28:56:5a:10:a7:c5',
#        'd0:7f:a0:05:2e:47', '00:12:cc:00:22:69', 'c0:d3:c0:61:58:c3',
# ...

# %%
s = df.rename({18 :"role" , 16:"mac"} , axis=1).groupby("role")["mac"].nunique()
s = (s/ s.sum()*100)
s = s.reset_index()
s = s[s["role"].str.find("role") > -1]
s
# Out:
#                                 role        mac
# 8          role=ur_diningsvcs_device   0.361991
# 9              role=ur_eduroam_guest   5.882353
# 10  role=ur_facstaff_personal_device  12.398190
# 11      role=ur_facstaff_uncc_device   7.782805
# 12     role=ur_guest_personal_device   0.271493
# 13              role=ur_halton_media   0.180995
# 14   role=ur_student_personal_device  71.493213
# 15       role=ur_student_uncc_device   0.904977

# %%
(

    ggplot(s , aes(x="role" , y="mac"))
    + geom_col()
    + coord_flip()
    + ylab("% of all Authenticated Usernames")
)
# Out:
# <ggplot: (149946011305)>

# %%
df
# Out:
#         0  1  2         3           4               5         6       7   \
# 0      Oct     4  00:00:03  10.47.0.23  authmgr[1889]:  <522008>  <3736>
# 1      Oct     4  00:00:09  10.47.0.22  authmgr[1858]:  <522008>  <1858>
# 2      Oct     4  00:00:09  10.47.0.22  authmgr[1858]:  <522008>  <1858>
# 3      Oct     4  00:00:09  10.47.0.22  authmgr[1858]:  <522008>  <1858>
# 4      Oct     4  00:00:14  10.47.0.33  authmgr[1899]:  <522008>  <1899>
# ...    ... .. ..       ...         ...             ...       ...     ...
# 40457  Oct     4  23:58:38  10.47.0.22  authmgr[1858]:  <522008>  <1858>
# 40458  Oct     4  23:58:42  10.47.0.22  authmgr[1858]:  <522008>  <1858>
# 40459  Oct     4  23:58:59  10.47.0.22  authmgr[1858]:  <522008>  <1858>
# 40460  Oct     4  23:59:03  10.47.0.22  authmgr[1858]:  <522008>  <3776>
# 40461  Oct     4  23:59:16  10.47.0.22  authmgr[1858]:  <522008>  <1858>
#
#            8  9   ...        19                       20            21   22  \
# ...

# %%
import requests

# %%
place = "fretwell"
sc = " university of north carolina at charlotte".replace(" " , "%20")
place = place + sc
gq = f"https://www.google.com/maps/search/{place}"
r = requests.get(gq , allow_redirects=True)

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r.text
# Out:
# '<!DOCTYPE html><html itemscope="" itemtype="http://schema.org/Place" lang="en"> <head> <link href="/maps/preview/opensearch.xml?hl=en" title="Google Maps" rel="search" type="application/opensearchdescription+xml"> <title>  Google Maps  </title> <meta content=" Find local businesses, view maps and get driving directions in Google Maps. " name="Description">  <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"> <meta content="chrome=1" http-equiv="X-UA-Compatible"> <meta content="notranslate" name="google"> <meta content="origin" name="referrer">   <meta content="Google Maps" itemprop="name"> <meta content="Google Maps" property="og:title"> <meta content="https://maps.google.com/maps/api/staticmap?center=35.3061604%2C-80.7289775&amp;zoom=17&amp;size=256x256&amp;language=en&amp;sensor=false&amp;client=google-maps-frontend&amp;signature=DmHr8R0AK3Im7JZOk_Ve9sSFfeU" itemprop="image"> <meta content="https://maps.google.com/maps/api/sta
# ...
